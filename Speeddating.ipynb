# %%
from sklearn import preprocessing
from scipy.io import arff
import pandas as pd
    `
data = arff.loadarff('speeddating.arff')
df = pd.DataFrame(data[0])
df.head()
# Out:
#   has_null  wave     gender   age  age_o  d_age   d_d_age  \
# 0     b'0'   1.0  b'female'  21.0   27.0    6.0  b'[4-6]'
# 1     b'0'   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 2     b'1'   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 3     b'0'   1.0  b'female'  21.0   23.0    2.0  b'[2-3]'
# 4     b'0'   1.0  b'female'  21.0   24.0    3.0  b'[2-3]'
#
#                                        race  \
# 0  b'Asian/Pacific Islander/Asian-American'
# 1  b'Asian/Pacific Islander/Asian-American'
# 2  b'Asian/Pacific Islander/Asian-American'
# 3  b'Asian/Pacific Islander/Asian-American'
# 4  b'Asian/Pacific Islander/Asian-American'
#
#                                      race_o samerace  ...  \
# 0            b'European/Caucasian-American'     b'0'  ...
# 1            b'European/Caucasian-American'     b'0'  ...
# 2  b'Asian/Pacific Islander/Asian-American'     b'1'  ...
# 3            b'European/Caucasian-American'     b'0'  ...
# ...

# %%
df.shape
# Out:
# (8378, 123)

# %%
#Convert byteStrings to Strings

str_df = df.select_dtypes([object]).stack().str.decode("utf-8").unstack()
#print(str_df)

for col in str_df:
    df[col] = str_df[col]
    
#df.head()

# %%
#Encode variables

# %%
df['race'].value_counts()
# Out:
# European/Caucasian-American              4727
# Asian/Pacific Islander/Asian-American    1982
# Latino/Hispanic American                  664
# Other                                     522
# Black/African American                    420
# ?                                          63
# Name: race, dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == "object" :
        le = preprocessing.LabelEncoder()
        le.fit(df[[col]])
        df[col] = le.fit_transform(df[[col]])
# Out:
# /Users/aidenjolibois/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/aidenjolibois/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/aidenjolibois/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df.head()
# Out:
#    has_null  wave  gender   age  age_o  d_age  d_d_age  race  race_o  \
# 0         0   1.0       0  21.0   27.0    6.0        2     1       3
# 1         0   1.0       0  21.0   22.0    1.0        0     1       3
# 2         1   1.0       0  21.0   22.0    1.0        0     1       1
# 3         0   1.0       0  21.0   23.0    2.0        1     1       3
# 4         0   1.0       0  21.0   24.0    3.0        1     1       4
#
#    samerace  ...  d_expected_num_interested_in_me  d_expected_num_matches  \
# 0         0  ...                                0                       1
# 1         0  ...                                0                       1
# 2         1  ...                                0                       1
# 3         0  ...                                0                       1
# 4         0  ...                                0                       1
#
#    like  guess_prob_liked  d_like  d_guess_prob_liked  met  decision  \
# ...

# %%
y = df["match"]

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 8373    0
# 8374    0
# 8375    0
# 8376    0
# 8377    0
# Name: match, Length: 8378, dtype: int64

# %%
df.shape
# Out:
# (8378, 123)

# %%
df['race'].value_counts()
# Out:
# 3    4727
# 1    1982
# 4     664
# 5     522
# 2     420
# 0      63
# Name: race, dtype: int64

# %%
df['d_d_age'].value_counts()
# Out:
# 1    2406
# 2    2316
# 0    2227
# 3    1429
# Name: d_d_age, dtype: int64

# %%
#Count of null values in each column

df[df.columns[df.isnull().any()]].isnull().sum()
# Out:
# age                                95
# age_o                             104
# importance_same_race               79
# importance_same_religion           79
# pref_o_attractive                  89
# pref_o_sincere                     89
# pref_o_intelligence                89
# pref_o_funny                       98
# pref_o_ambitious                  107
# pref_o_shared_interests           129
# attractive_o                      212
# sinsere_o                         287
# intelligence_o                    306
# funny_o                           360
# ambitous_o                        722
# shared_interests_o               1076
# attractive_important               79
# sincere_important                  79
# intellicence_important             79
# funny_important                    89
# ambtition_important                99
# shared_interests_important        121
# attractive                        105
# sincere                           105
# intelligence                      105
# ...

# %%
#remove expected_num_interested_in_me variabel (too many null values, too little importance)
#remove match, outcome variable is not included in the dataset 

df = df.drop(["expected_num_interested_in_me", "match"], axis=1)
#df[df.columns[df.isnull().any()]].isnull().sum()

# %% [markdown]
# Drop all columns with null vaules
# * there's potentially a better way to deal with null values

# %%
df = df.dropna() 
#new shape (4859 rows × 121 columns)

# %%
df = df.drop("has_null", axis = 1)

# %%
df.shape
# Out:
# (4859, 120)

# %%
X = df

# %%
X.head()
# Out:
#    wave  gender   age  age_o  d_age  d_d_age  race  race_o  samerace  \
# 0   1.0       0  21.0   27.0    6.0        2     1       3         0
# 1   1.0       0  21.0   22.0    1.0        0     1       3         0
# 3   1.0       0  21.0   23.0    2.0        1     1       3         0
# 4   1.0       0  21.0   24.0    3.0        1     1       4         0
# 5   1.0       0  21.0   25.0    4.0        2     1       3         0
#
#    importance_same_race  ...  d_expected_happy_with_sd_people  \
# 0                   2.0  ...                                0
# 1                   2.0  ...                                0
# 3                   2.0  ...                                0
# 4                   2.0  ...                                0
# 5                   2.0  ...                                0
#
#    d_expected_num_interested_in_me  d_expected_num_matches  like  \
# 0                                0                       1   7.0
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 8373    0
# 8374    0
# 8375    0
# 8376    0
# 8377    0
# Name: match, Length: 8378, dtype: int64

# %% [markdown]
# HOW TO DEAL WITH MISSSING VALUES?

# %% [markdown]
# Multicolinearity : Remove Difference in Age
# * age: Age of self
# * age_o: Age of partner
# * d_age: Difference in age

# %%
#df.drop(["d_age"],axis=1)

# %% [markdown]
# Arbitrary vairables: very subjective, don't contribute to regression
# * expected_happy_with_sd_people     101
# * expected_num_interested_in_me    6578
# * expected_num_matches             1173

# %%
#df.drop(["expected_num_interested_in_me",
#        "expected_happy_with_sd_people",
#        "expected_num_matches"],axis=1)

# %% [markdown]
# compliance - people who fully filled out survey more likely to be committed to looking for a match
